# %% [markdown]
# # Geocoding with libraries or APIs

# %% [markdown]
# ## Geocode a single address
#
# Use either of the code samples below to convert an address into latitude and longitude
#
# ```py
# import geocoder
#
# api_key = os.getenv(”api_key”)
#
# g = geocoder.google('2950 Broadway, New York, NY', key=os.getenv(”api_key”))
# g.latlng
# ```
#
# ```py
# from geopy.geocoders import GoogleV3
#
# geolocator = GoogleV3('AIzaSyAlfOExqbmgReJ7fBd5qvISVC5_w1yRRVM')
# address = geolocator.geocode('2950 Broadway, New York, NY')
# coords = [ address.latitude, address.longitude ]
# coords
# ```

# %% [markdown]
# # Read in our addresses
#
# We'll never ever ever read in data like this again. But we'll do it now, because we love lists of dictionaries.
#
# - ***Tip:** If you get a file not found error, make sure the `addresses.csv` is in the same location as this Jupyter notebook. Maybe do `!pwd` to see where the notebook is!*

# %%
import csv

with open('addresses.csv') as fp:
    data = list(csv.DictReader(fp))

data
# Out:
# [{'street': '100 Ihwajang-gil',
#   'city': 'Ihwa-dong',
#   'state': 'Jongno District',
#   'postal_code': 'Seoul',
#   'country': 'South Korea'},
#  {'street': '4 Chome-1-1 Shimomeguro',
#   'city': ' Meguro City',
#   'state': 'Tokyo',
#   'postal_code': '153-0064',
#   'country': 'Japan'},
#  {'street': '1126 Green Giant Ln',
#   'city': 'Blue Earth',
#   'state': 'MN',
#   'postal_code': '56013',
#   'country': ''},
#  {'street': '7477 Hubbard Ave',
#   'city': 'Middleton',
#   'state': 'WI',
#   'postal_code': '53562',
#   'country': None},
#  {'street': 'Wrocławska 12',
#   'city': '',
#   'state': 'Poznań',
#   'postal_code': '61-838',
#   'country': 'Poland'}]

# %% [markdown]
# ## Create the full addresses
#
# Loop through the list, creating a new `address` variable that includes the street, city, state, postal code and country. For now, just print it out.
#
# - ***Tip:** You can go really really far in crafting a perfect address for each result, but you might not need to.*
# - ***Tip:** You aren't making a list of addresses! Just printing it out.*

# %% [markdown]
# ## Geocode the address
#
# **Copy and paste the code from above into the cell below,** it will be your starting point.
#
# At the end of this step, you should have a list of dictionaries with two new keys: **lat** and **lon**, that are the latitude and longitude of the address. Gecode the addresses using either Google's geocoding API directly or the Geocoder library. You can use my API key: `AIzaSyAlfOExqbmgReJ7fBd5qvISVC5_w1yRRVM`
#
# - Google geocoding API documentation: https://developers.google.com/maps/documentation/geocoding/requests-geocoding
# - Geocoder documentation: https://geocoder.readthedocs.io/
#
# **You can also try another geocoder if you'd like!** I would have liked to *demand* a different API but hey it's 1:43PM and you need this homework *now*.
#
# **Tips:**
#
# * *What order are lat and long in???*
# * *You can do this by creating 100% new list of dicts or updating the old one inside of the loop.*

# %%
# Copy and paste the code from the "Create the full addresses" section

# %% [markdown]
# ## Save the results
#
# This is so embarrassing to be doing it like this but we're doing it anyway. **Pay attention to your key names for latitude and longitude.**

# %%
import csv

with open('addresses-geocoded.csv', 'w') as fp:
    fieldnames=['street','city','state','postal_code','country','lat', 'lon']

    writer = csv.DictWriter(fp, fieldnames=fieldnames)
    writer.writeheader()
    for row in data:
        writer.writerow(row)

# %% [markdown]
# # My Work

# %% [markdown]
# - $ pip install geocoder -> to be run on terminal
# - I checked where jupyter notebook is by doing !pwd. It is in /Users/ananyachaba/Downloads. That's where the addresses.csv file is as well.

# %%
# !pwd
# Out:
# /Users/ananyachaba/Downloads

# %%
import csv

with open('addresses.csv') as fp: # I don't understand this code!
    data = list(csv.DictReader(fp)) # I don't understand this code!

data
# Out:
# [{'street': '100 Ihwajang-gil',
#   'city': 'Ihwa-dong',
#   'state': 'Jongno District',
#   'postal_code': 'Seoul',
#   'country': 'South Korea'},
#  {'street': '4 Chome-1-1 Shimomeguro',
#   'city': ' Meguro City',
#   'state': 'Tokyo',
#   'postal_code': '153-0064',
#   'country': 'Japan'},
#  {'street': '1126 Green Giant Ln',
#   'city': 'Blue Earth',
#   'state': 'MN',
#   'postal_code': '56013',
#   'country': ''},
#  {'street': '7477 Hubbard Ave',
#   'city': 'Middleton',
#   'state': 'WI',
#   'postal_code': '53562',
#   'country': None},
#  {'street': 'Wrocławska 12',
#   'city': '',
#   'state': 'Poznań',
#   'postal_code': '61-838',
#   'country': 'Poland'}]

# %% [markdown]
# #### Loop through the list, creating a new `address` variable that includes the street, city, state, postal code and country. For now, just print it out.

# %%
for i in data:
    address= f"{i['street']}, {i['city']}, {i['state']}, {i['postal_code']}, {i['country']}"
    print(address)
# Out:
# 100 Ihwajang-gil, Ihwa-dong, Jongno District, Seoul, South Korea
# 4 Chome-1-1 Shimomeguro,  Meguro City, Tokyo, 153-0064, Japan
# 1126 Green Giant Ln, Blue Earth, MN, 56013,
# 7477 Hubbard Ave, Middleton, WI, 53562, None
# Wrocławska 12, , Poznań, 61-838, Poland

# %% [markdown]
# Now that we have our address, we'll start the process of converting them into latitudes and longitudes. I am using geocoder and using the documentation from here - https://geocoder.readthedocs.io/api.html#installation

# %%
import geocoder

# %% [markdown]
# Geocoder is a python library. It itself doesn't know every address's latitude and longitude on Earth. Instead, it sends a request to a geocoding service and brings back the result. But to access google, open street map via Geocoder, you need the API of that service. Geocoder is open source and simpler (maybe), not fully sure.
#
# - I just searched how to get google geocoder api
# - I reached here - https://developers.google.com/maps/documentation/geocoding/guides-v3/get-api-key
# - Then I realised that Soma has just given us the key and we don't need to put in billing information: api_key = 'AIzaSyAlfOExqbmgReJ7fBd5qvISVC5_w1yRRVM'

# %%
api_key = os.getenv('api_key')

# %%
#Trial 

g = geocoder.google('2950 Broadway, New York, NY', key=api_key)
g.latlng
# Out:
# [40.8076284, -73.963656]

# %% [markdown]
# Given that Soma has asked us to just print addresses, I am not making a new list out of them and reproducing the previous loop

# %%
for i in data:
    address= f"{i['street']}, {i['city']}, {i['state']}, {i['postal_code']}, {i['country']}"
    g = (geocoder.google(address, key=api_key)).latlng
    print(g)
    i["latitude"] = g[0]
    i["longitude"] = g[1]
# Out:
# [37.5798019, 127.0046643]
# [35.6317048, 139.706685]
# [43.6506445, -94.09570169999999]
# [43.0952876, -89.51123369999999]
# [52.4065344, 16.9327697]

# %%
data
# Out:
# [{'street': '100 Ihwajang-gil',
#   'city': 'Ihwa-dong',
#   'state': 'Jongno District',
#   'postal_code': 'Seoul',
#   'country': 'South Korea',
#   'latitude': 37.5798019,
#   'longitude': 127.0046643},
#  {'street': '4 Chome-1-1 Shimomeguro',
#   'city': ' Meguro City',
#   'state': 'Tokyo',
#   'postal_code': '153-0064',
#   'country': 'Japan',
#   'latitude': 35.6317048,
#   'longitude': 139.706685},
#  {'street': '1126 Green Giant Ln',
#   'city': 'Blue Earth',
#   'state': 'MN',
#   'postal_code': '56013',
#   'country': '',
#   'latitude': 43.6506445,
#   'longitude': -94.09570169999999},
#  {'street': '7477 Hubbard Ave',
#   'city': 'Middleton',
#   'state': 'WI',
#   'postal_code': '53562',
#   'country': None,
#   'latitude': 43.0952876,
#   'longitude': -89.51123369999999},
#  {'street': 'Wrocławska 12',
#   'city': '',
#   'state': 'Poznań',
#   'postal_code': '61-838',
#   'country': 'Poland',
#   'latitude': 52.4065344,
#   'longitude': 16.9327697}]

# %% [markdown]
# just writing things exactly as Soma asked us to:

# %%
import csv

with open('addresses-geocoded.csv', 'w') as fp:
    fieldnames=['street','city','state','postal_code','country','latitude', 'longitude']

    writer = csv.DictWriter(fp, fieldnames=fieldnames)
    writer.writeheader()
    for row in data:
        writer.writerow(row)

# %%
from dotenv import load_dotenv
load_dotenv()
import os
